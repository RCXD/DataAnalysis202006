# %%
import warnings
warnings.filterwarnings("ignore")
from IPython.display import Image
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.rcParams["font.size"] = 18
plt.rcParams["font.family"] = "NanumGothicCoding"
mpl.rcParams["axes.unicode_minus"] = False
import seaborn as sns
# %matplotlib inline
import missingno as msno
from plotnine import *

# %%
shop_2018 = pd.read_csv("./data/shop_201806_01.csv", encoding = "euc-kr") # cp949
shop_2018
# Out:
#           상가업소번호            상호명         지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       19905471         와라와라호프         NaN         Q       음식       Q09
# 1       19911397  커피빈코리아선릉로93길점  코리아선릉로93길점         Q       음식       Q12
# 2       19911801           프로포즈         NaN         Q       음식       Q09
# 3       19912201       싱싱커피&토스트         NaN         Q       음식       Q07
# 4       19932756       가락사우나내스낵         NaN         F    생활서비스       F09
# ...          ...            ...         ...       ...      ...       ...
# 499323  16141434       배스킨라빈스31     건대스타시티점         Q       음식       Q07
# 499324  16093390           본도시락        본설렁탕         Q       음식       Q01
# 499325  16093078         체크페이먼트         NaN         Q       음식       Q12
# 499326  16093122          마젠타네일         NaN         F    생활서비스       F01
# 499327  16093154           GS25       역촌대로점         D       소매       D03
#
#         상권업종중분류명 상권업종소분류코드     상권업종소분류명 표준산업분류코드  ...  \
# ...

# %%
# 소분류에 커피가 포함된 데이터만 추출한다.
coffee = shop_2018[shop_2018["상권업종소분류명"].str.contains("커피")]
coffee.shape
# Out:
# (20600, 39)

# %%
coffee["상호명"].unique().shape
# Out:
# (13718,)

# %%
coffee.loc[coffee["상호명"].str.contains("스타벅스"), "상호명"].unique()
# Out:
# array(['스타벅스종로3가점', '스타벅스커피여의도IFC1F', '스타벅스', '스타벅스신림사거리점', '스타벅스커피홍대역',
#        '스타벅스올림픽평화의문점', '스타벅스새문안로점', '스타벅스연신내역', '스타벅스연세백양로점',
#        '스타벅스가락시장역점', '스타벅스외대점', '스타벅스석촌역', '스타벅스명지대점', '스타벅스압구정로데오역',
#        '스타벅스연대동문', '스타벅스강남삼성타운점', '스타벅스서울대입구역점', '스타벅스신림점', '스타벅스광장점',
#        '스타벅스사당점', '스타벅스신촌명물거리점', '스타벅스명동미래', '스타벅스건국클래식점', '스타벅스연희DT점',
#        '스타벅스삼선교점', '스타벅스충정타워', '스타벅스올림픽공원북문점', '스타벅스커피여의도호성', '스타벅스이수역점',
#        '스타벅스방배카페입구', '스타벅스종각점', '스타벅스W-MALL점', '스타벅스용산역점', '스타벅스마포일진빌딩점',
#        '스타벅스천호로데오점', '스타벅스중계역점', '스타벅스명동메트로', '스타벅스마포아크로타워점',
#        '스타벅스남부터미널2점', '스타벅스구로디지털로점', '스타벅스중랑구청점', '스타벅스논현힐탑', '스타벅스종로관수점',
#        '스타벅스부산서면', '스타벅스삼성도심공항점', '스타벅스종로2가점', '스타벅스선정릉역점', '스타벅스미아역점',
#        '스타벅스선릉로점', '스타벅스커피신도림디큐브시티B2', '스타벅스역삼럭키', '스타벅스이태원거리점',
#        '스타벅스구로에이스트윈타워1점', '스타벅스을지로입구', '스타벅스교대역점', '스타벅스서울중앙우체국점',
#        '스타벅스삼성교점', '스타벅스남산스테이트', '스타벅스구로하이엔드점', '스타벅스명일이마트점',
#        '스타벅스조선호텔후문', '스타벅스목동점', '스타벅스커리학동사거리점', '스타벅스서울교대점',
# ...

# %%
coffee["시도명"].isnull().sum()
# Out:
# 0

# %%
coffee["시도명"].value_counts()
# Out:
# 서울특별시    16088
# 부산광역시     4512
# Name: 시도명, dtype: int64

# %%
ggplot(shop_2018, aes(x = "경도", y = "위도")) + geom_point() \
    + theme(text = element_text(family = "NanumGothicCoding"), figure_size = (8, 10))
# Out:
# <ggplot: (-9223371889014398667)>

# %%
shop_2018.plot.scatter(x = "경도", y = "위도", grid = True, figsize = (12, 16))

# %%
df_seoul = shop_2018[shop_2018["시도명"].str.startswith("서울")]
df_seoul
# Out:
#           상가업소번호            상호명         지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       19905471         와라와라호프         NaN         Q       음식       Q09
# 1       19911397  커피빈코리아선릉로93길점  코리아선릉로93길점         Q       음식       Q12
# 2       19911801           프로포즈         NaN         Q       음식       Q09
# 4       19932756       가락사우나내스낵         NaN         F    생활서비스       F09
# 5       19975850           허술한집         NaN         Q       음식       Q04
# ...          ...            ...         ...       ...      ...       ...
# 499323  16141434       배스킨라빈스31     건대스타시티점         Q       음식       Q07
# 499324  16093390           본도시락        본설렁탕         Q       음식       Q01
# 499325  16093078         체크페이먼트         NaN         Q       음식       Q12
# 499326  16093122          마젠타네일         NaN         F    생활서비스       F01
# 499327  16093154           GS25       역촌대로점         D       소매       D03
#
#         상권업종중분류명 상권업종소분류코드     상권업종소분류명 표준산업분류코드  ...  \
# ...

# %%
df_seoul.isnull().sum()
# Out:
# 상가업소번호            0
# 상호명               0
# 지점명          295853
# 상권업종대분류코드         0
# 상권업종대분류명          0
# 상권업종중분류코드         0
# 상권업종중분류명          0
# 상권업종소분류코드         0
# 상권업종소분류명          0
# 표준산업분류코드      19973
# 표준산업분류명       19973
# 시도코드              0
# 시도명               0
# 시군구코드             0
# 시군구명              0
# 행정동코드             0
# 행정동명              0
# 법정동코드             0
# 법정동명              0
# 지번코드              0
# 대지구분코드            0
# 대지구분명             0
# 지번본번지             0
# 지번부번지         66950
# 지번주소              0
# 도로명코드             0
# 도로명               0
# 건물본번지             0
# 건물부번지        303299
# 건물관리번호            0
# 건물명          180470
# 도로명주소             0
# 구우편번호             0
# 신우편번호             2
# 동정보          319409
# 층정보          102707
# 호정보          297152
# 경도                0
# 위도                0
# dtype: int64

# %%
df_seoul["상권업종대분류명"].value_counts()
# Out:
# 음식          112894
# 소매          106490
# 생활서비스        57266
# 학문/교육        27717
# 의료           15299
# 부동산          13164
# 관광/여가/오락      9536
# 숙박            2790
# 스포츠            112
# Name: 상권업종대분류명, dtype: int64

# %%
ggplot(df_seoul, aes(x = "상권업종대분류명")) + geom_bar(fill = "green") \
    + theme(text = element_text(family = "NanumGothicCoding"), figure_size = (12, 8)) \
    + coord_flip() \
    + ggtitle("상권업종대분류명")
# Out:
# <ggplot: (-9223371889081039374)>

# %%
plt.figure(figsize = (16, 12))
sns.countplot(data = df_seoul, y = "상권업종대분류명")

# %% [markdown]
# 상권업종대분류명 - 음식

# %%
df_food = df_seoul[df_seoul["상권업종대분류명"].str.contains("음식")]
df_food
# Out:
#           상가업소번호              상호명         지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       19905471           와라와라호프         NaN         Q       음식       Q09
# 1       19911397    커피빈코리아선릉로93길점  코리아선릉로93길점         Q       음식       Q12
# 2       19911801             프로포즈         NaN         Q       음식       Q09
# 5       19975850             허술한집         NaN         Q       음식       Q04
# 6       19977290             피자마루         약수점         Q       음식       Q07
# ...          ...              ...         ...       ...      ...       ...
# 499320  16138463             스타벅스       독립문역점         Q       음식       Q12
# 499322  16141060  간단하지만특별한화피디Cafe         앤아더         Q       음식       Q12
# 499323  16141434         배스킨라빈스31     건대스타시티점         Q       음식       Q07
# 499324  16093390             본도시락        본설렁탕         Q       음식       Q01
# 499325  16093078           체크페이먼트         NaN         Q       음식       Q12
#
#        상권업종중분류명 상권업종소분류코드     상권업종소분류명 표준산업분류코드  ...  \
# ...

# %%
ggplot(df_food, aes(x = "상권업종중분류명")) + geom_bar(fill = "green") \
    + theme(text = element_text(family = "NanumGothicCoding"), figure_size = (12, 8)) \
    + coord_flip() \
    + ggtitle("상권업종중분류명 - 음식")
# Out:
# <ggplot: (-9223371889081046931)>

# %%
plt.figure(figsize = (16, 12))
sns.countplot(data = df_food, y = "상권업종중분류명")

# %%
# 상권업종중분류명이 패스트푸드인 데이터만 추출한다.
df_fast_food = df_food.loc[df_food["상권업종중분류명"] == "패스트푸드"]
df_fast_food
# Out:
#           상가업소번호       상호명       지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 6       19977290      피자마루       약수점         Q       음식       Q07    패스트푸드
# 37      20107897      롯데리아      신림역점         Q       음식       Q07    패스트푸드
# 56      20581495    메가박스상봉       NaN         Q       음식       Q07    패스트푸드
# 60      20687182      본도시락      고려대점         Q       음식       Q07    패스트푸드
# 77      20665694    배스킨라빈스     관악구청점         Q       음식       Q07    패스트푸드
# ...          ...       ...       ...       ...      ...       ...      ...
# 498188  16150397  크리스피크림도넛      남영역점         Q       음식       Q07    패스트푸드
# 498384  16136577  명랑시대쌀핫도그      우장산점         Q       음식       Q07    패스트푸드
# 499170  16135616        델리      아메리칸         Q       음식       Q07    패스트푸드
# 499303  16176851        한스  케익경희궁자이점         Q       음식       Q07    패스트푸드
# 499323  16141434  배스킨라빈스31   건대스타시티점         Q       음식       Q07    패스트푸드
#
# ...

# %%
df_fast_food["상호명"].unique()
# Out:
# array(['피자마루', '롯데리아', '메가박스상봉', ..., '훌랄라참숯바베큐', '리코푸드코리아', '한스'],
#       dtype=object)

# %% [markdown]
# 배스킨라빈스와 던킨도너츠 입지분석

# %%
df_31 = df_seoul[df_seoul["상호명"].str.contains("배스킨|던킨")]
df_31
# Out:
#           상가업소번호            상호명       지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 77      20665694         배스킨라빈스     관악구청점         Q       음식       Q07
# 1545    19972402    던킨도너츠테크노마트점    테크노마트점         Q       음식       Q07
# 1881    20304915     던킨도너츠창동하나로       NaN         Q       음식       Q07
# 1910    20326167  던킨도너츠용산민자역사2호       NaN         Q       음식       Q07
# 2412    20578452          던킨도너츠     잠실본동점         Q       음식       Q07
# ...          ...            ...       ...       ...      ...       ...
# 482565  16139340       배스킨라빈스31     사당방배점         Q       음식       Q07
# 488012  16150533       배스킨라빈스31    송파하비오점         Q       음식       Q07
# 488013  16148456       배스킨라빈스31      강일동점         Q       음식       Q07
# 497223  16148489          던킨도너츠  왕십리민자역사점         Q       음식       Q07
# 499323  16141434       배스킨라빈스31   건대스타시티점         Q       음식       Q07
#
#        상권업종중분류명 상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# ...

# %%
df_31["상호명"].value_counts()
# Out:
# 배스킨라빈스31          108
# 던킨도너츠              86
# 배스킨라빈스             46
# 던킨도넛                4
# 배스킨라빈스31잠실월드점       1
#                  ...
# 배스킨라빈스31이수역점        1
# 배스킨라빈스브라운청담점        1
# 배스킨라빈스방이역점          1
# 던킨&아트샵              1
# 배스킨라빈스31영등포문래점      1
# Name: 상호명, Length: 206, dtype: int64

# %%
df_31.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
df_31 = df_31[['상호명', '지점명', '상권업종대분류명', '상권업종중분류명', '지번주소', 
              '도로명주소', '위도', '경도', '시군구명', '행정동명']]
df_31
# Out:
#                   상호명       지점명 상권업종대분류명 상권업종중분류명                    지번주소  \
# 77             배스킨라빈스     관악구청점       음식    패스트푸드    서울특별시 관악구 봉천동 863-13
# 1545      던킨도너츠테크노마트점    테크노마트점       음식    패스트푸드     서울특별시 광진구 구의동 546-4
# 1881       던킨도너츠창동하나로       NaN       음식    패스트푸드       서울특별시 도봉구 창동 1-10
# 1910    던킨도너츠용산민자역사2호       NaN       음식    패스트푸드  서울특별시 용산구 한강로3가 40-999
# 2412            던킨도너츠     잠실본동점       음식    패스트푸드     서울특별시 송파구 잠실동 242-9
# ...               ...       ...      ...      ...                     ...
# 482565       배스킨라빈스31     사당방배점       음식    패스트푸드     서울특별시 서초구 방배동 441-1
# 488012       배스킨라빈스31    송파하비오점       음식    패스트푸드       서울특별시 송파구 문정동 618
# 488013       배스킨라빈스31      강일동점       음식    패스트푸드       서울특별시 강동구 강일동 679
# 497223          던킨도너츠  왕십리민자역사점       음식    패스트푸드   서울특별시 성동구 행당동 168-151
# 499323       배스킨라빈스31   건대스타시티점       음식    패스트푸드     서울특별시 광진구 자양동 227-7
#
#                        도로명주소         위도          경도 시군구명  행정동명
# ...

# %%
# 브랜드명이라는 컬럼을 새로 만들고 배스킨라빈스와 던킨도너츠를 넣어준다.
df_31["브랜드명"] = ""
df_31.loc[df_31["상호명"].str.contains("배스킨"), "브랜드명"] = "배스킨라빈스"
df_31.loc[df_31["상호명"].str.contains("던킨"), "브랜드명"] = "던킨도너츠"
df_31
# Out:
#                   상호명       지점명 상권업종대분류명 상권업종중분류명                    지번주소  \
# 77             배스킨라빈스     관악구청점       음식    패스트푸드    서울특별시 관악구 봉천동 863-13
# 1545      던킨도너츠테크노마트점    테크노마트점       음식    패스트푸드     서울특별시 광진구 구의동 546-4
# 1881       던킨도너츠창동하나로       NaN       음식    패스트푸드       서울특별시 도봉구 창동 1-10
# 1910    던킨도너츠용산민자역사2호       NaN       음식    패스트푸드  서울특별시 용산구 한강로3가 40-999
# 2412            던킨도너츠     잠실본동점       음식    패스트푸드     서울특별시 송파구 잠실동 242-9
# ...               ...       ...      ...      ...                     ...
# 482565       배스킨라빈스31     사당방배점       음식    패스트푸드     서울특별시 서초구 방배동 441-1
# 488012       배스킨라빈스31    송파하비오점       음식    패스트푸드       서울특별시 송파구 문정동 618
# 488013       배스킨라빈스31      강일동점       음식    패스트푸드       서울특별시 강동구 강일동 679
# 497223          던킨도너츠  왕십리민자역사점       음식    패스트푸드   서울특별시 성동구 행당동 168-151
# 499323       배스킨라빈스31   건대스타시티점       음식    패스트푸드     서울특별시 광진구 자양동 227-7
#
#                        도로명주소         위도          경도 시군구명  행정동명    브랜드명
# ...

# %%
df_31["브랜드명"].value_counts()
# Out:
# 배스킨라빈스    298
# 던킨도너츠     148
# Name: 브랜드명, dtype: int64

# %%
df_31.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 446 entries, 77 to 499323
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   상호명       446 non-null    object
#  1   지점명       376 non-null    object
#  2   상권업종대분류명  446 non-null    object
#  3   상권업종중분류명  446 non-null    object
#  4   지번주소      446 non-null    object
#  5   도로명주소     446 non-null    object
#  6   위도        446 non-null    float64
#  7   경도        446 non-null    float64
#  8   시군구명      446 non-null    object
#  9   행정동명      446 non-null    object
#  10  브랜드명      446 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 41.8+ KB

# %%
ggplot(df_31, aes(x = "경도", y = "위도", fill="브랜드명")) + geom_point() \
    + theme(text = element_text(family = "NanumGothicCoding"), figure_size = (12, 8)) \
    + ggtitle("배스킨라빈스 & 던킨도너츠 상권분석")
# Out:
# <ggplot: (-9223371889075511941)>

# %%
plt.figure(figsize = (16, 12))
sns.scatterplot(data = df_31, x = "경도", y = "위도", hue = "브랜드명")

# %%
import folium

# %%
baskin_dunkin_map = folium.Map(location = [df_31["위도"].mean(), df_31["경도"].mean()], zoom_start = 12)

for i in df_31.index:
    
    if df_31.loc[i, "브랜드명"] == "배스킨라빈스":
        icon_color = "pink"
    else:
        icon_color = "blue"
    
    folium.Marker(
        location = [df_31.loc[i, "위도"], df_31.loc[i, "경도"]],
        popup = df_31.loc[i, "브랜드명"],
        icon = folium.Icon(color = icon_color)
    ).add_to(baskin_dunkin_map)
    
baskin_dunkin_map.save("./data/baskin_dunkin_map.html")
baskin_dunkin_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 뚜레쥬르, 파리바게뜨 매장 입지 분석

# %%
# contains() 메소드의 regex 옵션은 정규 표현식 사용 여부를 지정한다. 생략시 True이고 정규식이 적용되며 False를
# 사용하면 정규식이 적용되지 않는다.
df_seoul[df_seoul["상호명"].str.contains("뚜레(쥬|주)르|파리(바게|크라)", regex = True)]
# Out:
#           상가업소번호          상호명              지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 2358    20607348         뚜레쥬르              공릉점         Q       음식       Q08
# 11488   20013560   파리바게뜨상계제일점            상계제일점         Q       음식       Q08
# 11605   19996975  파리바게뜨길동사거리점           길동사거리점         Q       음식       Q08
# 12141   20021253  파리바게뜨-판매옥수점              옥수점         Q       음식       Q08
# 12416   20332682  파리바게뜨목동오거리점           목동오거리점         Q       음식       Q08
# ...          ...          ...              ...       ...      ...       ...
# 486878  16096341         뚜레쥬르  씨제이프레시웨이강남세브란스점         Q       음식       Q08
# 492569  16199721        파리바게뜨              정릉점         Q       음식       Q08
# 497546  16184184        파리바게뜨             반포제일         Q       음식       Q08
# 497972  16156505        파리바게뜨           마곡컨벤션점         Q       음식       Q08
# 498217  16113133        파리바게뜨             서울대점         Q       음식       Q08
#
# ...

# %%
df_pa = df_seoul[df_seoul["상호명"].str.contains("파스쿠", regex = True)]
df_pa["상호명"].value_counts()
# Out:
# 파스쿠찌               50
# 카페파스쿠찌              2
# 파리크라상파스쿠찌서          2
# 파스쿠찌선릉이노센스점         1
# 파스쿠찌서울대병원점          1
# 파스쿠찌메세나폴리스점         1
# 파스쿠찌삼성역점            1
# 파스쿠찌서초효령로           1
# 남산트라펠리스파스쿠찌         1
# 파스쿠찌신촌연세대점          1
# 파스쿠찌홍제역점            1
# 파스쿠찌커피              1
# 파스쿠찌한강자이타워점         1
# 파스쿠찌대학로점            1
# 파리크라상파스쿠찌홍          1
# 파스쿠치여의도점아이리스        1
# 파스쿠찌화곡역점            1
# 파스쿠찌동대문APM점         1
# 파스쿠찌LG트윈타워점         1
# 파스쿠치커피숍             1
# 파스쿠찌종각알파빌딩점         1
# 파스쿠찌국악고점            1
# 파스쿠찌연세세브란스2호        1
# 파리크라상파스쿠찌압구정역2호     1
# 파스쿠찌카페              1
# 카페파스쿠치              1
# 파스쿠찌테크노마트점          1
# Name: 상호명, dtype: int64

# %%
df_jam = df_seoul[df_seoul["상호명"].str.contains("잠바", regex = True)]
df_jam["상호명"].value_counts()
# Out:
# 잠바주스             4
# 잠바주스합정메세나폴리스점    1
# 잠바주스디큐브시티점       1
# 잠바주스청량리역사점       1
# 잠바주스한남더힐         1
# 파리크라상잠바주스동       1
# 잠바주스용산미군기지점      1
# 파리크라상잠바주스디큐브     1
# 잠바주스김포스카이파크점     1
# Name: 상호명, dtype: int64

# %%
# 파스쿠치와 잠바주스의 상호명에 파리크라상이 들어간 경우가 있기 때문에 파스쿠치와 잠바주스는 제외한다.

# %%
df_bread = df_seoul.loc[
    df_seoul["상호명"].str.contains("뚜레(쥬|주)르|파리(바게|크라)", regex = True) & 
    ~df_seoul["상호명"].str.contains("파스쿠|잠바", regex = True)
]
df_bread["상호명"].value_counts()
# Out:
# 파리바게뜨            211
# 뚜레쥬르             133
# 파리크라상             12
# 씨제이뚜레쥬르            2
# 파리바게뜨카페대학로점        2
#                 ...
# 파리바게뜨카페당산동행복점      1
# 뚜레쥬르신길삼거리          1
# 파리바게뜨강동경희          1
# 파리바게뜨카페하월곡동일점      1
# 뚜레쥬르엔시티보라매         1
# Name: 상호명, Length: 295, dtype: int64

# %%
df_bread.loc[df_bread["상호명"].str.contains("파리(바게|크라)"), "브랜드명"] = "파리바게뜨"
df_bread.loc[df_bread["상호명"].str.contains("뚜레(쥬|주)르"), "브랜드명"] = "뚜레쥬르"
df_bread["브랜드명"].value_counts()
# Out:
# 파리바게뜨    446
# 뚜레쥬르     206
# Name: 브랜드명, dtype: int64

# %%
ggplot(df_bread, aes(x = "경도", y = "위도", fill="브랜드명")) + geom_point() \
    + theme(text = element_text(family = "NanumGothicCoding"), figure_size = (12, 8)) \
    + ggtitle("파리바게뜨 & 뚜레쥬르 상권분석")
# Out:
# <ggplot: (147792595983)>

# %%
plt.figure(figsize = (16, 12))
sns.scatterplot(data = df_bread, x = "경도", y = "위도", hue = "브랜드명")

# %%
bread_map = folium.Map(location = [df_bread["위도"].mean(), df_bread["경도"].mean()], zoom_start = 12)

for i in df_bread.index:
    
    if df_bread.loc[i, "브랜드명"] == "파리바게뜨":
        icon_color = "pink"
    else:
        icon_color = "blue"
    
    folium.Marker(
        location = [df_bread.loc[i, "위도"], df_bread.loc[i, "경도"]],
        popup = df_bread.loc[i, "브랜드명"],
        icon = folium.Icon(color = icon_color)
    ).add_to(bread_map)
    
bread_map.save("./data/bread_map.html")
bread_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_seoul[df_seoul["상호명"].str.contains("스타벅스|starbucks|STARBUCKS", regex = True)]
# Out:
#           상가업소번호             상호명      지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 1619    19998811       스타벅스종로3가점    종로3가점         Q       음식       Q12
# 12478   20283351  스타벅스커피여의도IFC1F      NaN         Q       음식       Q12
# 12489   20288646            스타벅스     삼성역점         Q       음식       Q12
# 13539   20597950            스타벅스   신림포도몰점         Q       음식       Q12
# 13760   20825451      스타벅스신림사거리점   신림사거리점         Q       음식       Q12
# ...          ...             ...      ...       ...      ...       ...
# 495517  16185923            스타벅스      착한빵         Q       음식       Q12
# 495828  16161978            스타벅스  용산역써밋R점         Q       음식       Q12
# 497862  16184113            스타벅스      미스리         Q       음식       Q12
# 498901  16113431            스타벅스   송파개롱역점         Q       음식       Q12
# 499320  16138463            스타벅스    독립문역점         Q       음식       Q12
#
#        상권업종중분류명 상권업종소분류코드     상권업종소분류명 표준산업분류코드  ...  \
# 1619     커피점/카페    Q12A01  커피전문점/카페/다방   I56220  ...
# ...

# %%
df_seoul[df_seoul["상호명"].str.contains("이디야|ediya|EDIYA", regex = True)]
# Out:
#           상가업소번호    상호명      지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 1402    25435527  이디야커피     신길역점         Q       음식       Q12   커피점/카페
# 2433    20592419  이디야커피   이마트구로점         Q       음식       Q12   커피점/카페
# 7379    23258426  이디야커피  중계롯데우성점         Q       음식       Q12   커피점/카페
# 12312   20022357  이디야커피     금호역점         Q       음식       Q12   커피점/카페
# 12605   20264296  이디야커피      창신점         Q       음식       Q12   커피점/카페
# ...          ...    ...      ...       ...      ...       ...      ...
# 476208  16169240  이디야커피    석계역사점         Q       음식       Q12   커피점/카페
# 477092  16251644  이디야카페      NaN         Q       음식       Q12   커피점/카페
# 484780  16195232  이디야커피    에스프레소         Q       음식       Q12   커피점/카페
# 488161  16109492  이디야커피  세이브존노원점         Q       음식       Q12   커피점/카페
# 494194  16092257  이디야커피    잠원논현점         Q       음식       Q12   커피점/카페
#
#        상권업종소분류코드     상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# ...

# %%
df_cafe = df_seoul[df_seoul["상호명"].str.contains("스타벅스|starbucks|STARBUCKS|이디야|ediya|EDIYA", 
                                                regex = True)]
df_cafe
# Out:
#           상가업소번호        상호명      지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 1402    25435527      이디야커피     신길역점         Q       음식       Q12   커피점/카페
# 1619    19998811  스타벅스종로3가점    종로3가점         Q       음식       Q12   커피점/카페
# 2433    20592419      이디야커피   이마트구로점         Q       음식       Q12   커피점/카페
# 7379    23258426      이디야커피  중계롯데우성점         Q       음식       Q12   커피점/카페
# 12312   20022357      이디야커피     금호역점         Q       음식       Q12   커피점/카페
# ...          ...        ...      ...       ...      ...       ...      ...
# 495517  16185923       스타벅스      착한빵         Q       음식       Q12   커피점/카페
# 495828  16161978       스타벅스  용산역써밋R점         Q       음식       Q12   커피점/카페
# 497862  16184113       스타벅스      미스리         Q       음식       Q12   커피점/카페
# 498901  16113431       스타벅스   송파개롱역점         Q       음식       Q12   커피점/카페
# 499320  16138463       스타벅스    독립문역점         Q       음식       Q12   커피점/카페
#
# ...

# %%
df_cafe.loc[df_cafe["상호명"].str.contains("스타벅스|starbucks|STARBUCKS"), "브랜드명"] = "스타벅스"
df_cafe.loc[df_cafe["상호명"].str.contains("이디야|ediya|EDIYA"), "브랜드명"] = "이디야"
df_cafe["브랜드명"].value_counts()
# Out:
# 스타벅스    472
# 이디야     465
# Name: 브랜드명, dtype: int64

# %%
cafe_map = folium.Map(location = [df_cafe["위도"].mean(), df_cafe["경도"].mean()], zoom_start = 12)

for i in df_cafe.index:
    
    if df_cafe.loc[i, "브랜드명"] == "스타벅스":
        icon_color = "green"
    else:
        icon_color = "blue"
    
    folium.Marker(
        location = [df_cafe.loc[i, "위도"], df_cafe.loc[i, "경도"]],
        popup = df_cafe.loc[i, "브랜드명"],
        icon = folium.Icon(color = icon_color)
    ).add_to(cafe_map)
    
cafe_map.save("./data/cafe_map.html")
cafe_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
